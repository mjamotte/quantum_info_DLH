# %%
from qiskit.circuit import QuantumCircuit
from math import pi

# %% [markdown]
# # Exercice: Téléportation d'un état quantique

# %% [markdown]
# ![title](../figures/teleportation.png)

# %% [markdown]
# Téléportez l'état $\ket \psi = \ket 1$ en utilisant la paire de Bell $\frac{1}{\sqrt 2}(\ket{00} + \ket{11})$ et portes $C_X$ et $C_Z$:
#
# 1) Mesurer les trois qubits à la fin du circuit.
#
# 2) Testez votre circruit avec Aer (1000 shots).
#
# 3) Présentez les résulats dans un histogramme et interprétez les résulats.
#
# 4) Après vérification, envoyez votre circuit sur un QPU.
