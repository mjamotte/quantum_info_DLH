# %% [markdown]
# # Distribution quantique de clés

# %%
from qiskit.quantum_info import Statevector, Operator
from numpy import random

def print_formatted(data):
    formatted = '[' + ' '.join(str(x) for x in data) + ']'
    print(formatted)

# %% [markdown]
# **Alice:**

# %%
N = 32
alice_data_bits = [int(x) for x in random.randint(0,2,N)]
alice_op_labels = random.choice(['H', 'I'], N).tolist()

print_formatted(alice_data_bits)
print_formatted(alice_op_labels)

# %%
qubits = []
for i in range(N):
    data_bit = alice_data_bits[i]
    op_label = alice_op_labels[i]
    if op_label == 'I':
        if data_bit == 0:
            qubits.append(Statevector.from_label('0'))
        else:
            qubits.append(Statevector.from_label('1'))
    else:
        if data_bit == 0:
            qubits.append(Statevector.from_label('+'))
        else:
            qubits.append(Statevector.from_label('-'))

for i in range(5):
    display(qubits[i].draw('latex'))

# %% [markdown]
# **Alice:** Je t'envoie mes qubits...

# %%
# Safe transmission, no one is spying

# %% [markdown]
# **Bob:** Bien reçu!

# %%
bob_op_labels = random.choice(['H', 'I'], N).tolist()
print_formatted(bob_op_labels)

bob_measurements = []

for i in range(N):
    Op = Operator.from_label(bob_op_labels[i])
    q = qubits[i].evolve(Op)

    outcome, state = q.measure()
    measured_bit = int(outcome)
    bob_measurements.append(measured_bit)

print_formatted(bob_measurements)

# %% [markdown]
# **Alice:** Voilà les opérations aléatoires que j'ai utilisées

# %%
print_formatted(alice_op_labels)

# %% [markdown]
# **Bob:** Bien reçu! Voici les miennes:

# %%
print_formatted(bob_op_labels)

# %% [markdown]
# **Alice et Bob:** Sélectionnons les qubits ayant subit les mêmes opérations!
#
# (Ces qubits sont inchangés entre l'encodage et la lecture, car $HH=I$)

# %%
shared_data_bits = []

for i in range(N):
    if alice_op_labels[i] == bob_op_labels[i]:
        if alice_data_bits[i] == bob_measurements[i]:
            shared_data_bits.append(str(alice_data_bits[i]))
        else:
            shared_data_bits.append('x')
    else:
        shared_data_bits.append(' ')

print("Shared key:")
print_formatted(shared_data_bits)

# %% [markdown]
# Tableau résumé:

# %%
print_formatted(alice_data_bits)
print_formatted(alice_op_labels)
print_formatted(bob_op_labels)
print_formatted(bob_measurements)
print_formatted(shared_data_bits)

# %% [markdown]
# ## Exercice: écoute par une tierce personne
#
# Insérez le code ci-dessous au milieu du transfert de qubits entre Alice et Bob, afin de constater l'effet d'une écoute par Eve.

# %% [markdown]
# **Eve:**

# %%
eve_op_labels = random.choice(['H', 'I'], N).tolist()
eve_measurements = []

for i in range(N):
    Op = Operator.from_label(eve_op_labels[i])
    q = qubits[i].evolve(Op)

    outcome, state = q.measure()
    measured_bit = int(outcome)
    eve_measurements.append(measured_bit)

    #Eve alters the qubit state by performing the measurement
    qubits[i] = state

print_formatted(eve_op_labels)
print_formatted(eve_measurements)

# %% [markdown]
# Pour pallier à ce problème, Alice et Bob vérifient la qualité du transfert d'information en comparant une partie des bits partagés. Les bits restants constitueront la clé secrète.
#
# Enfin, la communication des qubits est certainement imparfaite, ce qui conduira naturellement à des clés différentes, même sans écoute par une personne tierce. Pour remédier à ce problème, il existe des techniques de *information reconciliation* et *privacy amplification*.
